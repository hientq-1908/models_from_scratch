# %%
import selectivesearch
from utils import extract_regions
from utils import show_image
from PIL import Image
import numpy as np
import pandas as pd
from trainer import Trainer
import os
# %load_ext autoreload
# %autoreload 2

# %%
cat_image = Image.open('cat.jpg')
regions = extract_regions(cat_image)
show_image(cat_image, bboxes=regions)

# %%
df_path = 'open-images-bus-trucks\df.csv'
df = pd.read_csv(df_path)
df
# Out:
#                 ImageID     Source LabelName  Confidence      XMin      XMax  \
# 0      0000599864fd15b3     xclick       Bus           1  0.343750  0.908750
# 1      00006bdb1eb5cd74     xclick     Truck           1  0.276667  0.697500
# 2      00006bdb1eb5cd74     xclick     Truck           1  0.702500  0.999167
# 3      00010bf498b64bab     xclick       Bus           1  0.156250  0.371250
# 4      00013f14dd4e168f     xclick       Bus           1  0.287500  0.999375
# ...                 ...        ...       ...         ...       ...       ...
# 24057  fff2b15ad6007d0e  activemil     Truck           1  0.277344  0.622656
# 24058  fff376d20410e4c9     xclick       Bus           1  0.295625  0.558750
# 24059  fff376d20410e4c9     xclick       Bus           1  0.348125  0.701250
# 24060  fffde5953a818927     xclick       Bus           1  0.277500  0.605625
# 24061  fffde5953a818927     xclick       Bus           1  0.613125  0.828750
#
# ...

# %%
# Overfitted model on 100 image traning set
img_dir = 'open-images-bus-trucks\images\images'
image = df.ImageID[3]
image = Image.open(os.path.join(img_dir, image+'.jpg'))
trainer = Trainer(dataset=None, load=True)
trainer.predict(image)
# Out:
# loaded successfully

# %%
image = df.ImageID[0]
image = Image.open(os.path.join(img_dir, image+'.jpg'))
image = np.asarray(image)
trainer.predict(image)

# %%
# problem with selective search

# %%
show_image(image, extract_regions(image))
